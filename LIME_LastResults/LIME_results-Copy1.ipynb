# %%
import nltk
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import unicodedata2
import math
import string
import tokenize
import sklearn
import re

data=pd.read_csv("df_MNB_TFIDF_class2.csv")

# %%
feature=list()
feature.append(data.feature1)
feature.append(data.feature2)
feature.append(data.feature3)
feature.append(data.feature4)
feature.append(data.feature5)
#print(feature)

# %%
len(feats)
# Out:
# 130580

# %%
feats=list()
for i in range(len(feature)):
    for j in range(len(feature[i])):
        feats.append(feature[i][j])

# %%
final=list()
for i in range(len(feats)):
    ft=feats[i].split(",")
    a1=re.search('\(\'([a-z]*)', ft[0])
    b1=re.search('(.*)\)', ft[1])
    final.append((a1.group(1),b1.group(1)))
    print(a1.group(1))
# Out:
# bicis
# hurto
# vez
# con
# va
# estacion
# por
# con
# los
# causal
# estacion
# vez
# por
# los
# sea
# meter
# por
# bolso
# sea
# hay
# los
# mujer
# va
# por
# por
# las
# del
# quien
# mas
# por
# que
# por
# con
# por
# con
# malparido
# con
# co
# gratis
# hay
# los
# por
# quien
# por
# por
# dios
# por
# que
# bmx
# hay
# por
# del
# por
# del
# del
# con
# que
# anos
# por
# bmx
# actuacion
# por
# por
# envian
# los
# por
# pasa
# por
# capacitacion
# por
# estacion
# los
# del
# por
# con
# por
# giron
# por
# popular
# por
# mortal
# con
# por
# mortal
# por
# asco
# gran
# con
# que
# preve
# por
# frente
# por
# en
# cayetanaat
# que
# con
# por
# story
# los
# mortal
# por
# final
# que
# del
# por
# por
# metrobus
# por
# mortal
# por
# del
# del
# les
# que
# frente
# les
# por
# por
# por
# por
# que
# con
# por
# frente
# las
# los
# con
# por
# por
# por
# quien
# frente
# frente
# por
# por
# que
# por
# con
# los
# hay
# que
# los
# seria
# por
# con
# los
# ...

# %%
def Sort_Tuple(tup):  
      
    # getting length of list of tuples 
    lst = len(tup)  
    for i in range(0, lst):  
          
        for j in range(0, lst-i-1):  
            if (tup[j][1] > tup[j + 1][1]):  
                temp = tup[j]  
                tup[j]= tup[j + 1]  
                tup[j + 1]= temp  
    return tup

# %%
result=(Sort_Tuple(final))
print(result)

# %%
result[-10:]

# %%
result[:10]
