# %%
import pickle

f = open('data_quantil_2016.pkl', 'rb')   # 'r' for reading; can be omitted
mydict = pickle.load(f)         # load file content as mydict
f.close()

# %%
import pandas as pd
unpickled_df = pd.read_pickle("data_quantil_2016.pkl")
unpickled_df
# Out:
#        TIPO_HECHO                                       TITULO_HECHO  \
# 0          DELITO           7 DELITOS CONTRA EL PATRIMONIO ECONÓMICO
# 1          DELITO           7 DELITOS CONTRA EL PATRIMONIO ECONÓMICO
# 2          DELITO  1 DELITOS CONTRA LA VIDA Y LA INTEGRIDAD PERSONAL
# 3          DELITO  1 DELITOS CONTRA LA VIDA Y LA INTEGRIDAD PERSONAL
# 4          DELITO  1 DELITOS CONTRA LA VIDA Y LA INTEGRIDAD PERSONAL
# ...           ...                                                ...
# 217527     DELITO  1 DELITOS CONTRA LA VIDA Y LA INTEGRIDAD PERSONAL
# 217528     DELITO           7 DELITOS CONTRA EL PATRIMONIO ECONÓMICO
# 217529     DELITO           7 DELITOS CONTRA EL PATRIMONIO ECONÓMICO
# 217530     DELITO           7 DELITOS CONTRA EL PATRIMONIO ECONÓMICO
# 217531     DELITO           7 DELITOS CONTRA EL PATRIMONIO ECONÓMICO
#
#                       HECHO CARACTERISTICA                ARMA_EMPLEADA  \
# ...

# %%
data_filt=unpickled_df.query("FECHA_HECHO >= '2019-03-18'and FECHA_HECHO <='2020-04-20'")
data_filt.sort_values('FECHA_HECHO')
# Out:
#        TIPO_HECHO                                       TITULO_HECHO  \
# 149061     DELITO  1 DELITOS CONTRA LA VIDA Y LA INTEGRIDAD PERSONAL
# 160102     DELITO           7 DELITOS CONTRA EL PATRIMONIO ECONÓMICO
# 142924     DELITO  1 DELITOS CONTRA LA VIDA Y LA INTEGRIDAD PERSONAL
# 141598     DELITO           7 DELITOS CONTRA EL PATRIMONIO ECONÓMICO
# 164993     DELITO           7 DELITOS CONTRA EL PATRIMONIO ECONÓMICO
# ...           ...                                                ...
# 194079     DELITO           7 DELITOS CONTRA EL PATRIMONIO ECONÓMICO
# 184875     DELITO  1 DELITOS CONTRA LA VIDA Y LA INTEGRIDAD PERSONAL
# 186650     DELITO           7 DELITOS CONTRA EL PATRIMONIO ECONÓMICO
# 204077     DELITO           7 DELITOS CONTRA EL PATRIMONIO ECONÓMICO
# 183861     DELITO  1 DELITOS CONTRA LA VIDA Y LA INTEGRIDAD PERSONAL
#
#                       HECHO CARACTERISTICA                ARMA_EMPLEADA  \
# ...

# %%
serie_total=data_filt['FECHA_HECHO'].value_counts().to_dict()
serie_total
# Out:
# {Timestamp('2019-12-07 00:00:00'): 247,
#  Timestamp('2019-12-25 00:00:00'): 245,
#  Timestamp('2020-01-01 00:00:00'): 233,
#  Timestamp('2019-06-15 00:00:00'): 223,
#  Timestamp('2019-11-30 00:00:00'): 210,
#  Timestamp('2019-12-08 00:00:00'): 210,
#  Timestamp('2019-04-27 00:00:00'): 201,
#  Timestamp('2019-04-06 00:00:00'): 199,
#  Timestamp('2019-03-31 00:00:00'): 199,
#  Timestamp('2019-05-12 00:00:00'): 193,
#  Timestamp('2019-03-30 00:00:00'): 191,
#  Timestamp('2019-05-25 00:00:00'): 191,
#  Timestamp('2020-03-06 00:00:00'): 186,
#  Timestamp('2019-08-30 00:00:00'): 184,
#  Timestamp('2019-04-12 00:00:00'): 183,
#  Timestamp('2019-06-16 00:00:00'): 181,
#  Timestamp('2019-05-17 00:00:00'): 179,
#  Timestamp('2019-10-31 00:00:00'): 179,
#  Timestamp('2019-06-02 00:00:00'): 179,
#  Timestamp('2019-08-31 00:00:00'): 178,
#  Timestamp('2019-07-03 00:00:00'): 178,
#  Timestamp('2019-09-21 00:00:00'): 178,
#  Timestamp('2019-05-11 00:00:00'): 173,
# ...

# %%
Serie_T = pd.DataFrame([[key, serie_total[key]] for key in serie_total.keys()], columns=['Tiempo', 'Cantidad'])
Serie_T=Serie_T.sort_values('Tiempo')
Serie_T
# Out:
#         Tiempo  Cantidad
# 175 2019-03-18       140
# 160 2019-03-19       142
# 52  2019-03-20       162
# 79  2019-03-21       155
# 92  2019-03-22       152
# ..         ...       ...
# 378 2020-04-16        37
# 367 2020-04-17        69
# 370 2020-04-18        52
# 369 2020-04-19        53
# 377 2020-04-20        38
#
# [400 rows x 2 columns]

# %%
Serie_T.to_csv('serie_total.csv', index=False)

# %% [markdown]
# # Por Tipo de Crimen

# %%
hurto=data_filt[data_filt.HECHO.isin(['HURTO A PERSONAS'])]
rinas=data_filt[data_filt.HECHO.isin(['LESIONES PERSONALES'])]
homicidio=data_filt[data_filt.HECHO.isin(['HOMICIDIOS'])]

# %%
serie_hurto=hurto['FECHA_HECHO'].value_counts().to_dict()
serie_rinas=rinas['FECHA_HECHO'].value_counts().to_dict()
serie_homic=homicidio['FECHA_HECHO'].value_counts().to_dict()

# %%
S_hurto = pd.DataFrame([[key, serie_hurto[key]] for key in serie_hurto.keys()], columns=['Tiempo', 'Cantidad'])
S_rinas = pd.DataFrame([[key, serie_rinas[key]] for key in serie_rinas.keys()], columns=['Tiempo', 'Cantidad'])
S_homic = pd.DataFrame([[key, serie_homic[key]] for key in serie_homic.keys()], columns=['Tiempo', 'Cantidad'])

S_hurto = S_hurto.sort_values('Tiempo')
S_rinas = S_rinas.sort_values('Tiempo')
S_homic = S_homic.sort_values('Tiempo')

# %%
S_hurto.to_csv('serie_hurto.csv', index=False)
S_rinas.to_csv('serie_rinas.csv', index=False)
S_homic.to_csv('serie_homicidio.csv', index=False)

# %% [markdown]
# # Por Localidad

# %%
Kennedy = data_filt[data_filt.LOCALIDAD.isin(['KENNEDY'])]
Engativa = data_filt[data_filt.LOCALIDAD.isin(['ENGATIVÁ'])]
Suba = data_filt[data_filt.LOCALIDAD.isin(['SUBA'])]
Usaquen = data_filt[data_filt.LOCALIDAD.isin(['USAQUÉN'])]
Chapinero = data_filt[data_filt.LOCALIDAD.isin(['CHAPINERO'])]
Santafe = data_filt[data_filt.LOCALIDAD.isin(['SANTA FE'])]
Bosa = data_filt[data_filt.LOCALIDAD.isin(['BOSA'])]
Teusaquillo = data_filt[data_filt.LOCALIDAD.isin(['TEUSAQUILLO'])]
Fontibon = data_filt[data_filt.LOCALIDAD.isin(['FONTIBÓN'])]
CiudadB = data_filt[data_filt.LOCALIDAD.isin(['CIUDAD BOLÍVAR'])]
Rafael = data_filt[data_filt.LOCALIDAD.isin(['RAFAEL URIBE URIBE'])]
Puentea = data_filt[data_filt.LOCALIDAD.isin(['PUENTE ARANDA'])]
Barrios = data_filt[data_filt.LOCALIDAD.isin(['BARRIOS UNIDOS'])]
SanCris = data_filt[data_filt.LOCALIDAD.isin(['SAN CRISTÓBAL'])]
Martires = data_filt[data_filt.LOCALIDAD.isin(['LOS MÁRTIRES'])]
Usme = data_filt[data_filt.LOCALIDAD.isin(['USME'])]
Tunjue = data_filt[data_filt.LOCALIDAD.isin(['TUNJUELITO'])]
Antonio = data_filt[data_filt.LOCALIDAD.isin(['ANTONIO NARIÑO'])]
Cande = data_filt[data_filt.LOCALIDAD.isin(['CANDELARIA'])]

# %%
serie_Kennedy = Kennedy['FECHA_HECHO'].value_counts().to_dict()
serie_Engativa = Engativa['FECHA_HECHO'].value_counts().to_dict()
serie_Suba = Suba['FECHA_HECHO'].value_counts().to_dict()
serie_Usaquen = Usaquen['FECHA_HECHO'].value_counts().to_dict()
serie_Chapinero = Chapinero['FECHA_HECHO'].value_counts().to_dict()
serie_Santafe = Santafe['FECHA_HECHO'].value_counts().to_dict()
serie_Bosa = Bosa['FECHA_HECHO'].value_counts().to_dict()
serie_Teusaquillo = Teusaquillo['FECHA_HECHO'].value_counts().to_dict()
serie_Fontibon = Fontibon['FECHA_HECHO'].value_counts().to_dict()
serie_CiudadB = CiudadB['FECHA_HECHO'].value_counts().to_dict()
serie_Rafael = Rafael['FECHA_HECHO'].value_counts().to_dict()
serie_Puentea = Puentea['FECHA_HECHO'].value_counts().to_dict()
serie_Barrios = Barrios['FECHA_HECHO'].value_counts().to_dict()
serie_SanCris = SanCris['FECHA_HECHO'].value_counts().to_dict()
serie_Martires = Martires['FECHA_HECHO'].value_counts().to_dict()
serie_Usme = Usme['FECHA_HECHO'].value_counts().to_dict()
serie_Tunjue = Tunjue['FECHA_HECHO'].value_counts().to_dict()
serie_Antonio = Antonio['FECHA_HECHO'].value_counts().to_dict()
serie_Cande = Cande['FECHA_HECHO'].value_counts().to_dict()

# %%
S_Kennedy = pd.DataFrame([[key, serie_Kennedy[key]] for key in serie_Kennedy.keys()], columns=['Tiempo', 'Cantidad'])
S_Kennedy = S_Kennedy.sort_values('Tiempo')
S_Kennedy.to_csv('serie_Kennedy.csv', index=False)

S_Engativa = pd.DataFrame([[key, serie_Engativa[key]] for key in serie_Engativa.keys()], columns=['Tiempo', 'Cantidad'])
S_Engativa = S_Engativa.sort_values('Tiempo')
S_Engativa.to_csv('serie_Engativa.csv', index=False)

S_Suba = pd.DataFrame([[key, serie_Suba[key]] for key in serie_Suba.keys()], columns=['Tiempo', 'Cantidad'])
S_Suba = S_Suba.sort_values('Tiempo')
S_Suba.to_csv('serie_Suba.csv', index=False)

S_Usaquen = pd.DataFrame([[key, serie_Usaquen[key]] for key in serie_Usaquen.keys()], columns=['Tiempo', 'Cantidad'])
S_Usaquen = S_Usaquen.sort_values('Tiempo')
S_Usaquen.to_csv('serie_Usaquen.csv', index=False)

S_Chapinero = pd.DataFrame([[key, serie_Chapinero[key]] for key in serie_Chapinero.keys()], columns=['Tiempo', 'Cantidad'])
S_Chapinero = S_Chapinero.sort_values('Tiempo')
S_Chapinero.to_csv('serie_Chapinero.csv', index=False)

S_Santafe = pd.DataFrame([[key, serie_Santafe[key]] for key in serie_Santafe.keys()], columns=['Tiempo', 'Cantidad'])
S_Santafe = S_Santafe.sort_values('Tiempo')
S_Santafe.to_csv('serie_Santafe.csv', index=False)

S_Bosa = pd.DataFrame([[key, serie_Bosa[key]] for key in serie_Bosa.keys()], columns=['Tiempo', 'Cantidad'])
S_Bosa = S_Bosa.sort_values('Tiempo')
S_Bosa.to_csv('serie_Bosa.csv', index=False)

S_Teusaquillo = pd.DataFrame([[key, serie_Teusaquillo[key]] for key in serie_Teusaquillo.keys()], columns=['Tiempo', 'Cantidad'])
S_Teusaquillo = S_Teusaquillo.sort_values('Tiempo')
S_Teusaquillo.to_csv('serie_Teusaquillo.csv', index=False)

S_Fontibon = pd.DataFrame([[key, serie_Fontibon[key]] for key in serie_Fontibon.keys()], columns=['Tiempo', 'Cantidad'])
S_Fontibon = S_Fontibon.sort_values('Tiempo')
S_Fontibon.to_csv('serie_Fontibon.csv', index=False)

S_CiudadB = pd.DataFrame([[key, serie_CiudadB[key]] for key in serie_CiudadB.keys()], columns=['Tiempo', 'Cantidad'])
S_CiudadB = S_CiudadB.sort_values('Tiempo')
S_CiudadB.to_csv('serie_CiudadBolivar.csv', index=False)

S_Rafael = pd.DataFrame([[key, serie_Rafael[key]] for key in serie_Rafael.keys()], columns=['Tiempo', 'Cantidad'])
S_Rafael = S_Rafael.sort_values('Tiempo')
S_Rafael.to_csv('serie_Rafael.csv', index=False)

S_Puentea = pd.DataFrame([[key, serie_Puentea[key]] for key in serie_Puentea.keys()], columns=['Tiempo', 'Cantidad'])
S_Puentea = S_Puentea.sort_values('Tiempo')
S_Puentea.to_csv('serie_Puentea.csv', index=False)

S_Barrios = pd.DataFrame([[key, serie_Barrios[key]] for key in serie_Barrios.keys()], columns=['Tiempo', 'Cantidad'])
S_Barrios = S_Barrios.sort_values('Tiempo')
S_Barrios.to_csv('serie_Barrios.csv', index=False)

S_SanCris = pd.DataFrame([[key, serie_SanCris[key]] for key in serie_SanCris.keys()], columns=['Tiempo', 'Cantidad'])
S_SanCris = S_SanCris.sort_values('Tiempo')
S_SanCris.to_csv('serie_SanCristobal.csv', index=False)

S_Martires = pd.DataFrame([[key, serie_Martires[key]] for key in serie_Martires.keys()], columns=['Tiempo', 'Cantidad'])
S_Martires = S_Martires.sort_values('Tiempo')
S_Martires.to_csv('serie_Martires.csv', index=False)

S_Usme = pd.DataFrame([[key, serie_Usme[key]] for key in serie_Usme.keys()], columns=['Tiempo', 'Cantidad'])
S_Usme = S_Usme.sort_values('Tiempo')
S_Usme.to_csv('serie_Usme.csv', index=False)

S_Tunjue = pd.DataFrame([[key, serie_Tunjue[key]] for key in serie_Tunjue.keys()], columns=['Tiempo', 'Cantidad'])
S_Tunjue = S_Tunjue.sort_values('Tiempo')
S_Tunjue.to_csv('serie_Tunjuelito.csv', index=False)

S_Antonio = pd.DataFrame([[key, serie_Antonio[key]] for key in serie_Antonio.keys()], columns=['Tiempo', 'Cantidad'])
S_Antonio = S_Antonio.sort_values('Tiempo')
S_Antonio.to_csv('serie_Antonio.csv', index=False)

S_Cande = pd.DataFrame([[key, serie_Cande[key]] for key in serie_Cande.keys()], columns=['Tiempo', 'Cantidad'])
S_Cande = S_Cande.sort_values('Tiempo')
S_Cande.to_csv('serie_Candelaria.csv', index=False)

# %% [markdown]
# # Por Localidad y tipo de Crimen

# %%
hurto_Kennedy = hurto[hurto.LOCALIDAD.isin(['KENNEDY'])]
hurto_Engativa = hurto[hurto.LOCALIDAD.isin(['ENGATIVÁ'])]
hurto_Suba = hurto[hurto.LOCALIDAD.isin(['SUBA'])]
hurto_Usaquen = hurto[hurto.LOCALIDAD.isin(['USAQUÉN'])]
hurto_Chapinero = hurto[hurto.LOCALIDAD.isin(['CHAPINERO'])]
hurto_Santafe = hurto[hurto.LOCALIDAD.isin(['SANTA FE'])]
hurto_Bosa = hurto[hurto.LOCALIDAD.isin(['BOSA'])]
hurto_Teusaquillo = hurto[hurto.LOCALIDAD.isin(['TEUSAQUILLO'])]
hurto_Fontibon = hurto[hurto.LOCALIDAD.isin(['FONTIBÓN'])]
hurto_CiudadB = hurto[hurto.LOCALIDAD.isin(['CIUDAD BOLÍVAR'])]
hurto_Rafael = hurto[hurto.LOCALIDAD.isin(['RAFAEL URIBE URIBE'])]
hurto_Puentea = hurto[hurto.LOCALIDAD.isin(['PUENTE ARANDA'])]
hurto_Barrios = hurto[hurto.LOCALIDAD.isin(['BARRIOS UNIDOS'])]
hurto_SanCris = hurto[hurto.LOCALIDAD.isin(['SAN CRISTÓBAL'])]
hurto_Martires = hurto[hurto.LOCALIDAD.isin(['LOS MÁRTIRES'])]
hurto_Usme = hurto[hurto.LOCALIDAD.isin(['USME'])]
hurto_Tunjue = hurto[hurto.LOCALIDAD.isin(['TUNJUELITO'])]
hurto_Antonio = hurto[hurto.LOCALIDAD.isin(['ANTONIO NARIÑO'])]
hurto_Cande = hurto[hurto.LOCALIDAD.isin(['CANDELARIA'])]

# %%
rinas_Kennedy = rinas[rinas.LOCALIDAD.isin(['KENNEDY'])]
rinas_Engativa = rinas[rinas.LOCALIDAD.isin(['ENGATIVÁ'])]
rinas_Suba = rinas[rinas.LOCALIDAD.isin(['SUBA'])]
rinas_Usaquen = rinas[rinas.LOCALIDAD.isin(['USAQUÉN'])]
rinas_Chapinero = rinas[rinas.LOCALIDAD.isin(['CHAPINERO'])]
rinas_Santafe = rinas[rinas.LOCALIDAD.isin(['SANTA FE'])]
rinas_Bosa = rinas[rinas.LOCALIDAD.isin(['BOSA'])]
rinas_Teusaquillo = rinas[rinas.LOCALIDAD.isin(['TEUSAQUILLO'])]
rinas_Fontibon = rinas[rinas.LOCALIDAD.isin(['FONTIBÓN'])]
rinas_CiudadB = rinas[rinas.LOCALIDAD.isin(['CIUDAD BOLÍVAR'])]
rinas_Rafael = rinas[rinas.LOCALIDAD.isin(['RAFAEL URIBE URIBE'])]
rinas_Puentea = rinas[rinas.LOCALIDAD.isin(['PUENTE ARANDA'])]
rinas_Barrios = rinas[rinas.LOCALIDAD.isin(['BARRIOS UNIDOS'])]
rinas_SanCris = rinas[rinas.LOCALIDAD.isin(['SAN CRISTÓBAL'])]
rinas_Martires = rinas[rinas.LOCALIDAD.isin(['LOS MÁRTIRES'])]
rinas_Usme = rinas[rinas.LOCALIDAD.isin(['USME'])]
rinas_Tunjue = rinas[rinas.LOCALIDAD.isin(['TUNJUELITO'])]
rinas_Antonio = rinas[rinas.LOCALIDAD.isin(['ANTONIO NARIÑO'])]
rinas_Cande = rinas[rinas.LOCALIDAD.isin(['CANDELARIA'])]

# %%
homicidio_Kennedy = homicidio[homicidio.LOCALIDAD.isin(['KENNEDY'])]
homicidio_Engativa = homicidio[homicidio.LOCALIDAD.isin(['ENGATIVÁ'])]
homicidio_Suba = homicidio[homicidio.LOCALIDAD.isin(['SUBA'])]
homicidio_Usaquen = homicidio[homicidio.LOCALIDAD.isin(['USAQUÉN'])]
homicidio_Chapinero = homicidio[homicidio.LOCALIDAD.isin(['CHAPINERO'])]
homicidio_Santafe = homicidio[homicidio.LOCALIDAD.isin(['SANTA FE'])]
homicidio_Bosa = homicidio[homicidio.LOCALIDAD.isin(['BOSA'])]
homicidio_Teusaquillo = homicidio[homicidio.LOCALIDAD.isin(['TEUSAQUILLO'])]
homicidio_Fontibon = homicidio[homicidio.LOCALIDAD.isin(['FONTIBÓN'])]
homicidio_CiudadB = homicidio[homicidio.LOCALIDAD.isin(['CIUDAD BOLÍVAR'])]
homicidio_Rafael = homicidio[homicidio.LOCALIDAD.isin(['RAFAEL URIBE URIBE'])]
homicidio_Puentea = homicidio[homicidio.LOCALIDAD.isin(['PUENTE ARANDA'])]
homicidio_Barrios = homicidio[homicidio.LOCALIDAD.isin(['BARRIOS UNIDOS'])]
homicidio_SanCris = homicidio[homicidio.LOCALIDAD.isin(['SAN CRISTÓBAL'])]
homicidio_Martires = homicidio[homicidio.LOCALIDAD.isin(['LOS MÁRTIRES'])]
homicidio_Usme = homicidio[homicidio.LOCALIDAD.isin(['USME'])]
homicidio_Tunjue = homicidio[homicidio.LOCALIDAD.isin(['TUNJUELITO'])]
homicidio_Antonio = homicidio[homicidio.LOCALIDAD.isin(['ANTONIO NARIÑO'])]
homicidio_Cande = homicidio[homicidio.LOCALIDAD.isin(['CANDELARIA'])]

# %%
serie_hurto_Kennedy = hurto_Kennedy['FECHA_HECHO'].value_counts().to_dict()
serie_hurto_Engativa = hurto_Engativa['FECHA_HECHO'].value_counts().to_dict()
serie_hurto_Suba = hurto_Suba['FECHA_HECHO'].value_counts().to_dict()
serie_hurto_Usaquen = hurto_Usaquen['FECHA_HECHO'].value_counts().to_dict()
serie_hurto_Chapinero = hurto_Chapinero['FECHA_HECHO'].value_counts().to_dict()
serie_hurto_Santafe = hurto_Santafe['FECHA_HECHO'].value_counts().to_dict()
serie_hurto_Bosa = hurto_Bosa['FECHA_HECHO'].value_counts().to_dict()
serie_hurto_Teusaquillo = hurto_Teusaquillo['FECHA_HECHO'].value_counts().to_dict()
serie_hurto_Fontibon = hurto_Fontibon['FECHA_HECHO'].value_counts().to_dict()
serie_hurto_CiudadB = hurto_CiudadB['FECHA_HECHO'].value_counts().to_dict()
serie_hurto_Rafael = hurto_Rafael['FECHA_HECHO'].value_counts().to_dict()
serie_hurto_Puentea = hurto_Puentea['FECHA_HECHO'].value_counts().to_dict()
serie_hurto_Barrios = hurto_Barrios['FECHA_HECHO'].value_counts().to_dict()
serie_hurto_SanCris = hurto_SanCris['FECHA_HECHO'].value_counts().to_dict()
serie_hurto_Martires = hurto_Martires['FECHA_HECHO'].value_counts().to_dict()
serie_hurto_Usme = hurto_Usme['FECHA_HECHO'].value_counts().to_dict()
serie_hurto_Tunjue = hurto_Tunjue['FECHA_HECHO'].value_counts().to_dict()
serie_hurto_Antonio = hurto_Antonio['FECHA_HECHO'].value_counts().to_dict()
serie_hurto_Cande = hurto_Cande['FECHA_HECHO'].value_counts().to_dict()

# %%
serie_rinas_Kennedy = rinas_Kennedy['FECHA_HECHO'].value_counts().to_dict()
serie_rinas_Engativa = rinas_Engativa['FECHA_HECHO'].value_counts().to_dict()
serie_rinas_Suba = rinas_Suba['FECHA_HECHO'].value_counts().to_dict()
serie_rinas_Usaquen = rinas_Usaquen['FECHA_HECHO'].value_counts().to_dict()
serie_rinas_Chapinero = rinas_Chapinero['FECHA_HECHO'].value_counts().to_dict()
serie_rinas_Santafe = rinas_Santafe['FECHA_HECHO'].value_counts().to_dict()
serie_rinas_Bosa = rinas_Bosa['FECHA_HECHO'].value_counts().to_dict()
serie_rinas_Teusaquillo = rinas_Teusaquillo['FECHA_HECHO'].value_counts().to_dict()
serie_rinas_Fontibon = rinas_Fontibon['FECHA_HECHO'].value_counts().to_dict()
serie_rinas_CiudadB = rinas_CiudadB['FECHA_HECHO'].value_counts().to_dict()
serie_rinas_Rafael = rinas_Rafael['FECHA_HECHO'].value_counts().to_dict()
serie_rinas_Puentea = rinas_Puentea['FECHA_HECHO'].value_counts().to_dict()
serie_rinas_Barrios = rinas_Barrios['FECHA_HECHO'].value_counts().to_dict()
serie_rinas_SanCris = rinas_SanCris['FECHA_HECHO'].value_counts().to_dict()
serie_rinas_Martires = rinas_Martires['FECHA_HECHO'].value_counts().to_dict()
serie_rinas_Usme = rinas_Usme['FECHA_HECHO'].value_counts().to_dict()
serie_rinas_Tunjue = rinas_Tunjue['FECHA_HECHO'].value_counts().to_dict()
serie_rinas_Antonio = rinas_Antonio['FECHA_HECHO'].value_counts().to_dict()
serie_rinas_Cande = rinas_Cande['FECHA_HECHO'].value_counts().to_dict()

# %%
serie_homicidio_Kennedy = homicidio_Kennedy['FECHA_HECHO'].value_counts().to_dict()
serie_homicidio_Engativa = homicidio_Engativa['FECHA_HECHO'].value_counts().to_dict()
serie_homicidio_Suba = homicidio_Suba['FECHA_HECHO'].value_counts().to_dict()
serie_homicidio_Usaquen = homicidio_Usaquen['FECHA_HECHO'].value_counts().to_dict()
serie_homicidio_Chapinero = homicidio_Chapinero['FECHA_HECHO'].value_counts().to_dict()
serie_homicidio_Santafe = homicidio_Santafe['FECHA_HECHO'].value_counts().to_dict()
serie_homicidio_Bosa = homicidio_Bosa['FECHA_HECHO'].value_counts().to_dict()
serie_homicidio_Teusaquillo = homicidio_Teusaquillo['FECHA_HECHO'].value_counts().to_dict()
serie_homicidio_Fontibon = homicidio_Fontibon['FECHA_HECHO'].value_counts().to_dict()
serie_homicidio_CiudadB = homicidio_CiudadB['FECHA_HECHO'].value_counts().to_dict()
serie_homicidio_Rafael = homicidio_Rafael['FECHA_HECHO'].value_counts().to_dict()
serie_homicidio_Puentea = homicidio_Puentea['FECHA_HECHO'].value_counts().to_dict()
serie_homicidio_Barrios = homicidio_Barrios['FECHA_HECHO'].value_counts().to_dict()
serie_homicidio_SanCris = homicidio_SanCris['FECHA_HECHO'].value_counts().to_dict()
serie_homicidio_Martires = homicidio_Martires['FECHA_HECHO'].value_counts().to_dict()
serie_homicidio_Usme = homicidio_Usme['FECHA_HECHO'].value_counts().to_dict()
serie_homicidio_Tunjue = homicidio_Tunjue['FECHA_HECHO'].value_counts().to_dict()
serie_homicidio_Antonio = homicidio_Antonio['FECHA_HECHO'].value_counts().to_dict()
serie_homicidio_Cande = homicidio_Cande['FECHA_HECHO'].value_counts().to_dict()

# %%
S_hurto_Kennedy = pd.DataFrame([[key, serie_hurto_Kennedy[key]] for key in serie_hurto_Kennedy.keys()], columns=['Tiempo', 'Cantidad'])
S_hurto_Kennedy = S_hurto_Kennedy.sort_values('Tiempo')
S_hurto_Kennedy.to_csv('serie_hurto_Kennedy.csv', index=False)

S_hurto_Engativa = pd.DataFrame([[key, serie_hurto_Engativa[key]] for key in serie_hurto_Engativa.keys()], columns=['Tiempo', 'Cantidad'])
S_hurto_Engativa = S_hurto_Engativa.sort_values('Tiempo')
S_hurto_Engativa.to_csv('serie_hurto_Engativa.csv', index=False)

S_hurto_Suba = pd.DataFrame([[key, serie_hurto_Suba[key]] for key in serie_hurto_Suba.keys()], columns=['Tiempo', 'Cantidad'])
S_hurto_Suba = S_hurto_Suba.sort_values('Tiempo')
S_hurto_Suba.to_csv('serie_hurto_Suba.csv', index=False)

S_hurto_Usaquen = pd.DataFrame([[key, serie_hurto_Usaquen[key]] for key in serie_hurto_Usaquen.keys()], columns=['Tiempo', 'Cantidad'])
S_hurto_Usaquen = S_hurto_Usaquen.sort_values('Tiempo')
S_hurto_Usaquen.to_csv('serie_hurto_Usaquen.csv', index=False)

S_hurto_Chapinero = pd.DataFrame([[key, serie_hurto_Chapinero[key]] for key in serie_hurto_Chapinero.keys()], columns=['Tiempo', 'Cantidad'])
S_hurto_Chapinero = S_hurto_Chapinero.sort_values('Tiempo')
S_hurto_Chapinero.to_csv('serie_hurto_Chapinero.csv', index=False)

S_hurto_Santafe = pd.DataFrame([[key, serie_hurto_Santafe[key]] for key in serie_hurto_Santafe.keys()], columns=['Tiempo', 'Cantidad'])
S_hurto_Santafe = S_hurto_Santafe.sort_values('Tiempo')
S_hurto_Santafe.to_csv('serie_hurto_Santafe.csv', index=False)

S_hurto_Bosa = pd.DataFrame([[key, serie_hurto_Bosa[key]] for key in serie_hurto_Bosa.keys()], columns=['Tiempo', 'Cantidad'])
S_hurto_Bosa = S_hurto_Bosa.sort_values('Tiempo')
S_hurto_Bosa.to_csv('serie_hurto_Bosa.csv', index=False)

S_hurto_Teusaquillo = pd.DataFrame([[key, serie_hurto_Teusaquillo[key]] for key in serie_hurto_Teusaquillo.keys()], columns=['Tiempo', 'Cantidad'])
S_hurto_Teusaquillo = S_hurto_Teusaquillo.sort_values('Tiempo')
S_hurto_Teusaquillo.to_csv('serie_hurto_Teusaquillo.csv', index=False)

S_hurto_Fontibon = pd.DataFrame([[key, serie_hurto_Fontibon[key]] for key in serie_hurto_Fontibon.keys()], columns=['Tiempo', 'Cantidad'])
S_hurto_Fontibon = S_hurto_Fontibon.sort_values('Tiempo')
S_hurto_Fontibon.to_csv('serie_hurto_Fontibon.csv', index=False)

S_hurto_CiudadB = pd.DataFrame([[key, serie_hurto_CiudadB[key]] for key in serie_hurto_CiudadB.keys()], columns=['Tiempo', 'Cantidad'])
S_hurto_CiudadB = S_hurto_CiudadB.sort_values('Tiempo')
S_hurto_CiudadB.to_csv('serie_hurto_CiudadBolivar.csv', index=False)

S_hurto_Rafael = pd.DataFrame([[key, serie_hurto_Rafael[key]] for key in serie_hurto_Rafael.keys()], columns=['Tiempo', 'Cantidad'])
S_hurto_Rafael = S_hurto_Rafael.sort_values('Tiempo')
S_hurto_Rafael.to_csv('serie_hurto_Rafael.csv', index=False)

S_hurto_Puentea = pd.DataFrame([[key, serie_hurto_Puentea[key]] for key in serie_hurto_Puentea.keys()], columns=['Tiempo', 'Cantidad'])
S_hurto_Puentea = S_hurto_Puentea.sort_values('Tiempo')
S_hurto_Puentea.to_csv('serie_hurto_Puentea.csv', index=False)

S_hurto_Barrios = pd.DataFrame([[key, serie_hurto_Barrios[key]] for key in serie_hurto_Barrios.keys()], columns=['Tiempo', 'Cantidad'])
S_hurto_Barrios = S_hurto_Barrios.sort_values('Tiempo')
S_hurto_Barrios.to_csv('serie_hurto_Barrios.csv', index=False)

S_hurto_SanCris = pd.DataFrame([[key, serie_hurto_SanCris[key]] for key in serie_hurto_SanCris.keys()], columns=['Tiempo', 'Cantidad'])
S_hurto_SanCris = S_hurto_SanCris.sort_values('Tiempo')
S_hurto_SanCris.to_csv('serie_hurto_SanCristobal.csv', index=False)

S_hurto_Martires = pd.DataFrame([[key, serie_hurto_Martires[key]] for key in serie_hurto_Martires.keys()], columns=['Tiempo', 'Cantidad'])
S_hurto_Martires = S_hurto_Martires.sort_values('Tiempo')
S_hurto_Martires.to_csv('serie_hurto_Martires.csv', index=False)

S_hurto_Usme = pd.DataFrame([[key, serie_hurto_Usme[key]] for key in serie_hurto_Usme.keys()], columns=['Tiempo', 'Cantidad'])
S_hurto_Usme = S_hurto_Usme.sort_values('Tiempo')
S_hurto_Usme.to_csv('serie_hurto_Usme.csv', index=False)

S_hurto_Tunjue = pd.DataFrame([[key, serie_hurto_Tunjue[key]] for key in serie_hurto_Tunjue.keys()], columns=['Tiempo', 'Cantidad'])
S_hurto_Tunjue = S_hurto_Tunjue.sort_values('Tiempo')
S_hurto_Tunjue.to_csv('serie_hurto_Tunjuelito.csv', index=False)

S_hurto_Antonio = pd.DataFrame([[key, serie_hurto_Antonio[key]] for key in serie_hurto_Antonio.keys()], columns=['Tiempo', 'Cantidad'])
S_hurto_Antonio = S_hurto_Antonio.sort_values('Tiempo')
S_hurto_Antonio.to_csv('serie_hurto_Antonio.csv', index=False)

S_hurto_Cande = pd.DataFrame([[key, serie_hurto_Cande[key]] for key in serie_hurto_Cande.keys()], columns=['Tiempo', 'Cantidad'])
S_hurto_Cande = S_hurto_Cande.sort_values('Tiempo')
S_hurto_Cande.to_csv('serie_hurto_Candelaria.csv', index=False)

# %%
S_rinas_Kennedy = pd.DataFrame([[key, serie_rinas_Kennedy[key]] for key in serie_rinas_Kennedy.keys()], columns=['Tiempo', 'Cantidad'])
S_rinas_Kennedy = S_rinas_Kennedy.sort_values('Tiempo')
S_rinas_Kennedy.to_csv('serie_rinas_Kennedy.csv', index=False)

S_rinas_Engativa = pd.DataFrame([[key, serie_rinas_Engativa[key]] for key in serie_rinas_Engativa.keys()], columns=['Tiempo', 'Cantidad'])
S_rinas_Engativa = S_rinas_Engativa.sort_values('Tiempo')
S_rinas_Engativa.to_csv('serie_rinas_Engativa.csv', index=False)

S_rinas_Suba = pd.DataFrame([[key, serie_rinas_Suba[key]] for key in serie_rinas_Suba.keys()], columns=['Tiempo', 'Cantidad'])
S_rinas_Suba = S_rinas_Suba.sort_values('Tiempo')
S_rinas_Suba.to_csv('serie_rinas_Suba.csv', index=False)

S_rinas_Usaquen = pd.DataFrame([[key, serie_rinas_Usaquen[key]] for key in serie_rinas_Usaquen.keys()], columns=['Tiempo', 'Cantidad'])
S_rinas_Usaquen = S_rinas_Usaquen.sort_values('Tiempo')
S_rinas_Usaquen.to_csv('serie_rinas_Usaquen.csv', index=False)

S_rinas_Chapinero = pd.DataFrame([[key, serie_rinas_Chapinero[key]] for key in serie_rinas_Chapinero.keys()], columns=['Tiempo', 'Cantidad'])
S_rinas_Chapinero = S_rinas_Chapinero.sort_values('Tiempo')
S_rinas_Chapinero.to_csv('serie_rinas_Chapinero.csv', index=False)

S_rinas_Santafe = pd.DataFrame([[key, serie_rinas_Santafe[key]] for key in serie_rinas_Santafe.keys()], columns=['Tiempo', 'Cantidad'])
S_rinas_Santafe = S_rinas_Santafe.sort_values('Tiempo')
S_rinas_Santafe.to_csv('serie_rinas_Santafe.csv', index=False)

S_rinas_Bosa = pd.DataFrame([[key, serie_rinas_Bosa[key]] for key in serie_rinas_Bosa.keys()], columns=['Tiempo', 'Cantidad'])
S_rinas_Bosa = S_rinas_Bosa.sort_values('Tiempo')
S_rinas_Bosa.to_csv('serie_rinas_Bosa.csv', index=False)

S_rinas_Teusaquillo = pd.DataFrame([[key, serie_rinas_Teusaquillo[key]] for key in serie_rinas_Teusaquillo.keys()], columns=['Tiempo', 'Cantidad'])
S_rinas_Teusaquillo = S_rinas_Teusaquillo.sort_values('Tiempo')
S_rinas_Teusaquillo.to_csv('serie_rinas_Teusaquillo.csv', index=False)

S_rinas_Fontibon = pd.DataFrame([[key, serie_rinas_Fontibon[key]] for key in serie_rinas_Fontibon.keys()], columns=['Tiempo', 'Cantidad'])
S_rinas_Fontibon = S_rinas_Fontibon.sort_values('Tiempo')
S_rinas_Fontibon.to_csv('serie_rinas_Fontibon.csv', index=False)

S_rinas_CiudadB = pd.DataFrame([[key, serie_rinas_CiudadB[key]] for key in serie_rinas_CiudadB.keys()], columns=['Tiempo', 'Cantidad'])
S_rinas_CiudadB = S_rinas_CiudadB.sort_values('Tiempo')
S_rinas_CiudadB.to_csv('serie_rinas_CiudadBolivar.csv', index=False)

S_rinas_Rafael = pd.DataFrame([[key, serie_rinas_Rafael[key]] for key in serie_rinas_Rafael.keys()], columns=['Tiempo', 'Cantidad'])
S_rinas_Rafael = S_rinas_Rafael.sort_values('Tiempo')
S_rinas_Rafael.to_csv('serie_rinas_Rafael.csv', index=False)

S_rinas_Puentea = pd.DataFrame([[key, serie_rinas_Puentea[key]] for key in serie_rinas_Puentea.keys()], columns=['Tiempo', 'Cantidad'])
S_rinas_Puentea = S_rinas_Puentea.sort_values('Tiempo')
S_rinas_Puentea.to_csv('serie_rinas_Puentea.csv', index=False)

S_rinas_Barrios = pd.DataFrame([[key, serie_rinas_Barrios[key]] for key in serie_rinas_Barrios.keys()], columns=['Tiempo', 'Cantidad'])
S_rinas_Barrios = S_rinas_Barrios.sort_values('Tiempo')
S_rinas_Barrios.to_csv('serie_rinas_Barrios.csv', index=False)

S_rinas_SanCris = pd.DataFrame([[key, serie_rinas_SanCris[key]] for key in serie_rinas_SanCris.keys()], columns=['Tiempo', 'Cantidad'])
S_rinas_SanCris = S_rinas_SanCris.sort_values('Tiempo')
S_rinas_SanCris.to_csv('serie_rinas_SanCristobal.csv', index=False)

S_rinas_Martires = pd.DataFrame([[key, serie_rinas_Martires[key]] for key in serie_rinas_Martires.keys()], columns=['Tiempo', 'Cantidad'])
S_rinas_Martires = S_rinas_Martires.sort_values('Tiempo')
S_rinas_Martires.to_csv('serie_rinas_Martires.csv', index=False)

S_rinas_Usme = pd.DataFrame([[key, serie_rinas_Usme[key]] for key in serie_rinas_Usme.keys()], columns=['Tiempo', 'Cantidad'])
S_rinas_Usme = S_rinas_Usme.sort_values('Tiempo')
S_rinas_Usme.to_csv('serie_rinas_Usme.csv', index=False)

S_rinas_Tunjue = pd.DataFrame([[key, serie_rinas_Tunjue[key]] for key in serie_rinas_Tunjue.keys()], columns=['Tiempo', 'Cantidad'])
S_rinas_Tunjue = S_rinas_Tunjue.sort_values('Tiempo')
S_rinas_Tunjue.to_csv('serie_rinas_Tunjuelito.csv', index=False)

S_rinas_Antonio = pd.DataFrame([[key, serie_rinas_Antonio[key]] for key in serie_rinas_Antonio.keys()], columns=['Tiempo', 'Cantidad'])
S_rinas_Antonio = S_rinas_Antonio.sort_values('Tiempo')
S_rinas_Antonio.to_csv('serie_rinas_Antonio.csv', index=False)

S_rinas_Cande = pd.DataFrame([[key, serie_rinas_Cande[key]] for key in serie_rinas_Cande.keys()], columns=['Tiempo', 'Cantidad'])
S_rinas_Cande = S_rinas_Cande.sort_values('Tiempo')
S_rinas_Cande.to_csv('serie_rinas_Candelaria.csv', index=False)

# %%
S_homicidio_Kennedy = pd.DataFrame([[key, serie_homicidio_Kennedy[key]] for key in serie_homicidio_Kennedy.keys()], columns=['Tiempo', 'Cantidad'])
S_homicidio_Kennedy = S_homicidio_Kennedy.sort_values('Tiempo')
S_homicidio_Kennedy.to_csv('serie_homicidio_Kennedy.csv', index=False)

S_homicidio_Engativa = pd.DataFrame([[key, serie_homicidio_Engativa[key]] for key in serie_homicidio_Engativa.keys()], columns=['Tiempo', 'Cantidad'])
S_homicidio_Engativa = S_homicidio_Engativa.sort_values('Tiempo')
S_homicidio_Engativa.to_csv('serie_homicidio_Engativa.csv', index=False)

S_homicidio_Suba = pd.DataFrame([[key, serie_homicidio_Suba[key]] for key in serie_homicidio_Suba.keys()], columns=['Tiempo', 'Cantidad'])
S_homicidio_Suba = S_homicidio_Suba.sort_values('Tiempo')
S_homicidio_Suba.to_csv('serie_homicidio_Suba.csv', index=False)

S_homicidio_Usaquen = pd.DataFrame([[key, serie_homicidio_Usaquen[key]] for key in serie_homicidio_Usaquen.keys()], columns=['Tiempo', 'Cantidad'])
S_homicidio_Usaquen = S_homicidio_Usaquen.sort_values('Tiempo')
S_homicidio_Usaquen.to_csv('serie_homicidio_Usaquen.csv', index=False)

S_homicidio_Chapinero = pd.DataFrame([[key, serie_homicidio_Chapinero[key]] for key in serie_homicidio_Chapinero.keys()], columns=['Tiempo', 'Cantidad'])
S_homicidio_Chapinero = S_homicidio_Chapinero.sort_values('Tiempo')
S_homicidio_Chapinero.to_csv('serie_homicidio_Chapinero.csv', index=False)

S_homicidio_Santafe = pd.DataFrame([[key, serie_homicidio_Santafe[key]] for key in serie_homicidio_Santafe.keys()], columns=['Tiempo', 'Cantidad'])
S_homicidio_Santafe = S_homicidio_Santafe.sort_values('Tiempo')
S_homicidio_Santafe.to_csv('serie_homicidio_Santafe.csv', index=False)

S_homicidio_Bosa = pd.DataFrame([[key, serie_homicidio_Bosa[key]] for key in serie_homicidio_Bosa.keys()], columns=['Tiempo', 'Cantidad'])
S_homicidio_Bosa = S_homicidio_Bosa.sort_values('Tiempo')
S_homicidio_Bosa.to_csv('serie_homicidio_Bosa.csv', index=False)

S_homicidio_Teusaquillo = pd.DataFrame([[key, serie_homicidio_Teusaquillo[key]] for key in serie_homicidio_Teusaquillo.keys()], columns=['Tiempo', 'Cantidad'])
S_homicidio_Teusaquillo = S_homicidio_Teusaquillo.sort_values('Tiempo')
S_homicidio_Teusaquillo.to_csv('serie_homicidio_Teusaquillo.csv', index=False)

S_homicidio_Fontibon = pd.DataFrame([[key, serie_homicidio_Fontibon[key]] for key in serie_homicidio_Fontibon.keys()], columns=['Tiempo', 'Cantidad'])
S_homicidio_Fontibon = S_homicidio_Fontibon.sort_values('Tiempo')
S_homicidio_Fontibon.to_csv('serie_homicidio_Fontibon.csv', index=False)

S_homicidio_CiudadB = pd.DataFrame([[key, serie_homicidio_CiudadB[key]] for key in serie_homicidio_CiudadB.keys()], columns=['Tiempo', 'Cantidad'])
S_homicidio_CiudadB = S_homicidio_CiudadB.sort_values('Tiempo')
S_homicidio_CiudadB.to_csv('serie_homicidio_CiudadBolivar.csv', index=False)

S_homicidio_Rafael = pd.DataFrame([[key, serie_homicidio_Rafael[key]] for key in serie_homicidio_Rafael.keys()], columns=['Tiempo', 'Cantidad'])
S_homicidio_Rafael = S_homicidio_Rafael.sort_values('Tiempo')
S_homicidio_Rafael.to_csv('serie_homicidio_Rafael.csv', index=False)

S_homicidio_Puentea = pd.DataFrame([[key, serie_homicidio_Puentea[key]] for key in serie_homicidio_Puentea.keys()], columns=['Tiempo', 'Cantidad'])
S_homicidio_Puentea = S_homicidio_Puentea.sort_values('Tiempo')
S_homicidio_Puentea.to_csv('serie_homicidio_Puentea.csv', index=False)

S_homicidio_Barrios = pd.DataFrame([[key, serie_homicidio_Barrios[key]] for key in serie_homicidio_Barrios.keys()], columns=['Tiempo', 'Cantidad'])
S_homicidio_Barrios = S_homicidio_Barrios.sort_values('Tiempo')
S_homicidio_Barrios.to_csv('serie_homicidio_Barrios.csv', index=False)

S_homicidio_SanCris = pd.DataFrame([[key, serie_homicidio_SanCris[key]] for key in serie_homicidio_SanCris.keys()], columns=['Tiempo', 'Cantidad'])
S_homicidio_SanCris = S_homicidio_SanCris.sort_values('Tiempo')
S_homicidio_SanCris.to_csv('serie_homicidio_SanCristobal.csv', index=False)

S_homicidio_Martires = pd.DataFrame([[key, serie_homicidio_Martires[key]] for key in serie_homicidio_Martires.keys()], columns=['Tiempo', 'Cantidad'])
S_homicidio_Martires = S_homicidio_Martires.sort_values('Tiempo')
S_homicidio_Martires.to_csv('serie_homicidio_Martires.csv', index=False)

S_homicidio_Usme = pd.DataFrame([[key, serie_homicidio_Usme[key]] for key in serie_homicidio_Usme.keys()], columns=['Tiempo', 'Cantidad'])
S_homicidio_Usme = S_homicidio_Usme.sort_values('Tiempo')
S_homicidio_Usme.to_csv('serie_homicidio_Usme.csv', index=False)

S_homicidio_Tunjue = pd.DataFrame([[key, serie_homicidio_Tunjue[key]] for key in serie_homicidio_Tunjue.keys()], columns=['Tiempo', 'Cantidad'])
S_homicidio_Tunjue = S_homicidio_Tunjue.sort_values('Tiempo')
S_homicidio_Tunjue.to_csv('serie_homicidio_Tunjuelito.csv', index=False)

S_homicidio_Antonio = pd.DataFrame([[key, serie_homicidio_Antonio[key]] for key in serie_homicidio_Antonio.keys()], columns=['Tiempo', 'Cantidad'])
S_homicidio_Antonio = S_homicidio_Antonio.sort_values('Tiempo')
S_homicidio_Antonio.to_csv('serie_homicidio_Antonio.csv', index=False)

S_homicidio_Cande = pd.DataFrame([[key, serie_homicidio_Cande[key]] for key in serie_homicidio_Cande.keys()], columns=['Tiempo', 'Cantidad'])
S_homicidio_Cande = S_homicidio_Cande.sort_values('Tiempo')
S_homicidio_Cande.to_csv('serie_homicidio_Candelaria.csv', index=False)
