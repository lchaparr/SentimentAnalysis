# %%
import nltk
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import unicodedata2
import math
import string
import tokenize
import sklearn
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.tokenize import wordpunct_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import RegexpTokenizer
from nltk.tokenize import sent_tokenize
from sklearn import metrics
from sklearn.metrics.pairwise import linear_kernel
from sklearn.metrics.pairwise import polynomial_kernel
from sklearn.naive_bayes import MultinomialNB
from string import digits
from xml.dom import minidom
from unidecode import unidecode
from nltk.stem.snowball import SnowballStemmer
from string import punctuation
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn.naive_bayes import MultinomialNB,BernoulliNB
from sklearn.linear_model import LogisticRegression,SGDClassifier
from sklearn.svm import SVC
import csv

# %%
data=pd.read_csv("../predict_data_to_score.csv")

# %%
id=[]

# %%
for i in range(len(data.Text)):
    id.append(i)

# %%
data['ID']=id

# %%
data.head()
# Out:
#                TweetId                CreatedAt  \
# 0  1111016644380381189  2019-03-27 21:26:24.000
# 1  1111004064190550016  2019-03-27 20:36:25.000
# 2  1110985764110827522  2019-03-27 19:23:41.000
# 3  1110984479743586306  2019-03-27 19:18:35.000
# 4  1110974209025630208  2019-03-27 18:37:46.000
#
#                                                 Text  Sentiment  \
# 0  Definitivamente estámos muy mal. Es el colmo N...        NaN
# 1  Imaginate! ¿Los videos no son una prueba? Para...        NaN
# 2  No le pregunten a la Policia, preguntenle a nu...        NaN
# 3  El único culpable de ello es @JuanManSantos po...        NaN
# 4                                    ¿Denunció ella?        NaN
#
#    SentimentSimple  SentimentPolarity  ID
# 0              NaN                NaN   0
# 1              NaN                NaN   1
# 2              NaN                NaN   2
# 3              NaN                NaN   3
# 4              NaN                NaN   4

# %%
data.to_csv('../predict_data_to_score.csv', index=False)

# %%
data.drop('SentimentSimple', inplace=True, axis=1)

# %%
data.drop('SentimentPolarity', inplace=True, axis=1)

# %%
data.drop('Sentiment', inplace=True, axis=1)

# %%
data.to_csv('../predict_data_to_score.csv', index=False)

# %%
data['Count']=0

# %%
data.to_csv('../predict_data_to_score.csv', index=False)

# %%
data.head()
# Out:
#                TweetId                CreatedAt  \
# 0  1111016644380381189  2019-03-27 21:26:24.000
# 1  1111004064190550016  2019-03-27 20:36:25.000
# 2  1110985764110827522  2019-03-27 19:23:41.000
# 3  1110984479743586306  2019-03-27 19:18:35.000
# 4  1110974209025630208  2019-03-27 18:37:46.000
#
#                                                 Text  ID  Sentiment
# 0  Definitivamente estámos muy mal. Es el colmo N...   0          1
# 1  Imaginate! ¿Los videos no son una prueba? Para...   1          1
# 2  No le pregunten a la Policia, preguntenle a nu...   2          1
# 3  El único culpable de ello es @JuanManSantos po...   3          1
# 4                                    ¿Denunció ella?   4          1

# %%
data['Sentiment']=1

# %%
data.rename(columns={"Text": "Tweet"})
# Out:
#                     TweetId                CreatedAt  \
# 0       1111016644380381189  2019-03-27 21:26:24.000
# 1       1111004064190550016  2019-03-27 20:36:25.000
# 2       1110985764110827522  2019-03-27 19:23:41.000
# 3       1110984479743586306  2019-03-27 19:18:35.000
# 4       1110974209025630208  2019-03-27 18:37:46.000
# ...                     ...                      ...
# 146783  1255116425418756099  2020-04-28 12:47:29.000
# 146784  1255117975700545536  2020-04-28 12:53:39.000
# 146785  1255119546907865089  2020-04-28 12:59:53.000
# 146786  1255120249801891844  2020-04-28 13:02:41.000
# 146787  1255120132696915968  2020-04-28 13:02:13.000
#
#                                                     Tweet      ID  Sentiment
# 0       Definitivamente estámos muy mal. Es el colmo N...       0          1
# 1       Imaginate! ¿Los videos no son una prueba? Para...       1          1
# 2       No le pregunten a la Policia, preguntenle a nu...       2          1
# ...
